# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv (r'C:\Users\USER\Desktop\PF\fetal_health.csv')

# %%
df.head(7)
# Out:
#    baseline value  accelerations  fetal_movement  uterine_contractions  \
# 0           120.0          0.000             0.0                 0.000
# 1           132.0          0.006             0.0                 0.006
# 2           133.0          0.003             0.0                 0.008
# 3           134.0          0.003             0.0                 0.008
# 4           132.0          0.007             0.0                 0.008
# 5           134.0          0.001             0.0                 0.010
# 6           134.0          0.001             0.0                 0.013
#
#    light_decelerations  severe_decelerations  prolongued_decelerations  \
# 0                0.000                   0.0                     0.000
# 1                0.003                   0.0                     0.000
# 2                0.003                   0.0                     0.000
# 3                0.003                   0.0                     0.000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 22 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   baseline value                                          2126 non-null   float64
#  1   accelerations                                           2126 non-null   float64
#  2   fetal_movement                                          2126 non-null   float64
#  3   uterine_contractions                                    2126 non-null   float64
#  4   light_decelerations                                     2126 non-null   float64
#  5   severe_decelerations                                    2126 non-null   float64
#  6   prolongued_decelerations                                2126 non-null   float64
#  7   abnormal_short_term_variability                         2126 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# baseline value                                            0
# accelerations                                             0
# fetal_movement                                            0
# uterine_contractions                                      0
# light_decelerations                                       0
# severe_decelerations                                      0
# prolongued_decelerations                                  0
# abnormal_short_term_variability                           0
# mean_value_of_short_term_variability                      0
# percentage_of_time_with_abnormal_long_term_variability    0
# mean_value_of_long_term_variability                       0
# histogram_width                                           0
# histogram_min                                             0
# histogram_max                                             0
# histogram_number_of_peaks                                 0
# histogram_number_of_zeroes                                0
# ...

# %%
df.columns
# Out:
# Index(['baseline value', 'accelerations', 'fetal_movement',
#        'uterine_contractions', 'light_decelerations', 'severe_decelerations',
#        'prolongued_decelerations', 'abnormal_short_term_variability',
#        'mean_value_of_short_term_variability',
#        'percentage_of_time_with_abnormal_long_term_variability',
#        'mean_value_of_long_term_variability', 'histogram_width',
#        'histogram_min', 'histogram_max', 'histogram_number_of_peaks',
#        'histogram_number_of_zeroes', 'histogram_mode', 'histogram_mean',
#        'histogram_median', 'histogram_variance', 'histogram_tendency',
#        'fetal_health'],
#       dtype='object')

# %% [markdown]
# ##### 1. What is the total number of records in the dataset?

# %%
print(" Total number of records in this dataset:", len(df))
# Out:
#  Total number of records in this dataset: 2126

# %% [markdown]
# ##### 2. How many unique fetal health categories are present?

# %%
unique_FH= df['fetal_health'].value_counts()
print("The unique fetal health categories in this dataset:", unique_FH)
# Out:
# The unique fetal health categories in this dataset: fetal_health
# 1.0    1655
# 2.0     295
# 3.0     176
# Name: count, dtype: int64

# %% [markdown]
# ##### 3. What is the standard deviation of the baseline value?

# %%
print(df['baseline value'].std())
# Out:
# 9.84084425772098

# %% [markdown]
# ##### 4. What is the average baseline heart rate?

# %%
average_baseline = df['baseline value'].mean()
print("The average baseline is:", average_baseline)
# Out:
# The average baseline is: 133.3038570084666

# %% [markdown]
# ##### 5. What is the average histogram mean?

# %%
average_histomean = df['histogram_mean'].mean()
print("The average histogram mean:", average_histomean)
# Out:
# The average histogram mean: 134.61053621825025

# %% [markdown]
# ##### 6.  What is the median histogram mode?

# %%
histogram_mode_median = df['histogram_mode'].median()
print("Median histogram mode:", histogram_mode_median)
# Out:
# Median histogram mode: 139.0

# %% [markdown]
# ##### 7. What is the mean uterine contraction rate?

# %%
uterine_contractions_mean = df['uterine_contractions'].mean()
print("Mean uterine contraction rate:", uterine_contractions_mean)
# Out:
# Mean uterine contraction rate: 0.004366415804327376

# %% [markdown]
# ##### 8. What is the percentage of records with severe decelerations?

# %%
severe_decelerations_count = len(df[df['severe_decelerations'] > 0])
severe_decelerations_percentage = (severe_decelerations_count / len(df)) * 100
print("Percentage of records with severe decelerations:", severe_decelerations_percentage)
# Out:
# Percentage of records with severe decelerations: 0.3292568203198495

# %% [markdown]
# ##### 9. What is the correlation between the baseline value and fetal movement?

# %%
cor = df['baseline value'].corr(df['fetal_movement'])
print("The correlation between baseline value and fetal movement", cor)
# Out:
# The correlation between baseline value and fetal movement -0.033436480203972795

# %% [markdown]
# ##### 10. What is the correlation between the baseline value and severe decelerations?

# %%
print(df['baseline value'].corr(df['severe_decelerations']))
# Out:
# -0.053517549897532844

# %% [markdown]
# ##### 11.  Compare the mean of all numerical columns across fetal health categories

# %%
means_by_category = df.groupby('fetal_health').mean().sum()
print("Mean of all numerical columns by fetal health category:",means_by_category)
# Out:
# Mean of all numerical columns by fetal health category: baseline value                                            405.354119
# accelerations                                               0.004659
# fetal_movement                                              0.041971
# uterine_contractions                                        0.010955
# light_decelerations                                         0.006147
# severe_decelerations                                        0.000035
# prolongued_decelerations                                    0.001419
# abnormal_short_term_variability                           168.907329
# mean_value_of_short_term_variability                        3.645186
# percentage_of_time_with_abnormal_long_term_variability     56.921812
# mean_value_of_long_term_variability                        20.320237
# histogram_width                                           200.905913
# histogram_min                                             288.363670
# ...

# %% [markdown]
# ##### 12. Calculate the skewness of uterine contractions

# %%
skewness_contractions = df['uterine_contractions'].skew()
print("Skewness of uterine contractions:", skewness_contractions)
# Out:
# Skewness of uterine contractions: 0.15931454606098208

# %% [markdown]
# ##### 13. What is the relationship between the baseline value and histogram mode?

# %%
plt.scatter(df['baseline value'], df['histogram_mode'])
plt.figure(figsize=(6,4))
plt.show()

# %% [markdown]
# ##### 14. What is the distribution of prolongued decelerations?

# %%
df['prolongued_decelerations'].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# ##### 15. Plot the distribution of baseline heart rate

# %%
plt.figure(figsize=(4,2))
sns.histplot(df['baseline value'], kde=True, bins=20)
plt.title('Distribution of Baseline Heart Rate')
plt.xlabel('Baseline Value')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ##### 16. Plot the count of each fetal health category.

# %%
plt.figure(figsize=(4, 2))
sns.countplot(x='fetal_health', data=df, palette='viridis')
plt.title('Count of Fetal Health Categories')
plt.xlabel('Fetal Health')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_19348\1293493600.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='fetal_health', data=df, palette='viridis')

# %% [markdown]
# ##### 17. Plot a scatter plot of histogram variance vs histogram mode

# %%
plt.figure(figsize=(4, 2))
sns.scatterplot(x='histogram_mode', y='histogram_variance', hue='fetal_health', data=df, palette='cool')
plt.title('Scatter Plot of Histogram Mode vs Variance')
plt.xlabel('Histogram Mode')
plt.ylabel('Histogram Variance')
plt.show()

# %% [markdown]
# ##### 18.  Create a pairplot for selected features.

# %%
plt.figure(figsize=(4,2))
sns.pairplot(df, vars=['baseline value', 'accelerations', 'mean_value_of_short_term_variability', 'fetal_health'], hue='fetal_health', palette='husl')
plt.show()

# %% [markdown]
# ##### The above pairplot is a collection of scatter plots and histograms that analyze various characteristics and relationships in this dataset. Here's a breakdown of what each plot represents:
#
# ###### * The top left histogram shows the distribution of a variable called "baseline_value".
# ###### * The top middle scatter plot shows the relationship between "accelerations" and an unknown variable.
# ###### * The top right scatter plot shows the relationship between a variable called "fetal_health" and another variable, potentially "mean_value_of_short_term_variability".
# ###### * The bottom left scatter plot shows the relationship between two other variables, potentially related to fetal health or development.
# ###### * The bottom middle scatter plot shows the relationship between two more variables, potentially related to the fetal health or development.
# ###### * The bottom right scatter plot shows the relationship between the "fetal_health" variable and another variable, potentially a measure of overall health or development.
# ###### Overall, this analysis is exploring various aspects of fetal health and development, potentially in the context of a medical or biological study. The scatter plots and histograms are used to visualize the relationships and distributions of the different variables being measured or observed.
